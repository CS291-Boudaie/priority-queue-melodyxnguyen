# %% [markdown]
# # Priority Queue

# %% [markdown]
# You can use this jupyter notebook to test and debug your min heap.
#
# If you are unsure what a jupyter notebook is, open the "jupyter_tutorial" notebook.
#
# If you are not confident with your Python abilities, open the "python_tutorial" notebook.

# %% [markdown]
# # Importing the Heap
#
# You can import classes from Python files like below. The block is Jupyter "magic" that will reload the MinHeap if you make any changes while running this notebook.

# %%
# %load_ext autoreload
# %autoreload 2
print("loaded successfully")

# %%
from priority_queue.priority_queue import MinHeap, PriorityQueue

# %% [markdown]
# Let's try creating a Min Heap and adding some things to it:

# %%
h = MinHeap()
print(h.is_empty())   # True
print(len(h))         # 0
print(h.peek())       # None
# Out:
# True
# 0
# None

# %%
mh = MinHeap()
print(len(mh))  # Should be 0
print(mh.is_empty())  # Should be True
mh.add(10, 'A')
print(len(mh))  # Should be 1
# Out:
# 0
# True
# 1

# %%
mh = MinHeap()
print(len(mh))  # Should be 0
print(mh.is_empty())  # Should be True
mh.add(10, 'A')
print(len(mh))  # Should be 1
print(mh.is_empty())  # Should be False
mh.add(20, 'B')
print(len(mh))  # Should be 2
mh.add(8, 'C')
print(len(mh))  # Should be 3
# Out:
# 0
# True
# 1
# False
# 2
# 3

# %% [markdown]
# Based on what you inputted, "C" with the priority of 8 should be the highest priority.

# %%
print(mh.peek())  # Should be (8, "C")
print(len(mh))  # Should still be 3
print('----')
# Now let's pop it

prio, item = mh.pop_min()
print(prio)  # Should be 8
print(item)  # Should be "C"
print(len(mh))  # Should be 2 now.

# %% [markdown]
# Play around with the heap yourself, see what errors you can catch. E.g. try to clear out the priority queue. You can create new cells below by pressing the `+` button above. I'll leave a few for you.

# %% [markdown]
# # Priority Queue
# The Priority Queue should have the same behavior, since it uses the Min Heap internally. Test it as well to make sure you are comfortable with it.

# %%
q = PriorityQueue()
print(q.is_empty())
q.add(4, "A")
q.add(3, "B")
q.add(2, "C")

print(q.pop())
print(q.pop())
print(q.pop())
# Out:
# True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 print(q.is_empty())
#       3 q.add(4, "A")
# ----> 4 q.add(3, "B")
#       5 q.add(2, "C")
#       7 print(q.pop())
#
# File ~/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/priority_queue/priority_queue.py:133, in add(self, priority, item)
#     132 def pop(self):
# --> 133     return self.heap.pop_min()
#
# File ~/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/priority_queue/priority_queue.py:64, in MinHeap.add(self, priority, item)
#      60 def add(self, priority, item):
#      61     # TODO: Add (priority, item) to end of list
#      62     # Then bubble it UP into correct position
#      63     self.data.append((priority, item))
# ---> 64     self._bubble_up(len(self.data) -1)
#
# File ~/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/priority_queue/priority_queue.py:5, in _bubble_up(self, idx)
#       1 # In this file, you will develop a Min Heap to use in a priority queue.
#       2 # A priority queue is a fundamental data structure for many of the algorithms we will cover in this class,
#       3 # so it is important to get the fundamentals right.
#       4
# ----> 5 # In a normal queue, you insert items, and they are removed in first-in, first-out order (FIFO).
#       6 # In a priority queue, you insert an arbitrary object AND a priority value for that item.
#       7 # When an item is requested, the item with the lowest priority value is returned (and removed).
#       8 # Read more: https://en.wikipedia.org/wiki/Priority_queue
#       9
#      10 # Fundamental to the Priority Queue is the "Heap" data structure.
#      11 # Heaps (especially min-heaps) allow for fast retrieval of the smallest-priority element,
#      12 # and efficient re-ordering after inserts/removals.
#      13 # Once you have a heap, implementing a Priority Queue is straightforward.
#      14
#      15 # A min-heap can be thought of as a binary tree where each node has priority <= its children.
#      16 # This means the smallest-priority element will always be at index 0.
#      17
#      18 # The tree is stored in a list. For a node at index i:
#      19 # left child index = 2*i + 1
#      20 # right child index = 2*i + 2
#      21 # parent index = (i - 1) // 2
#      22
#      23 # When you add an item, append it to the end of the list, then "bubble up"
#      24 # by swapping it with its parent while it has a smaller priority than the parent.
#      25
#      26 # When you pop the minimum item, you remove and return the item at index 0.
#      27 # Then move the last element to index 0 and "bubble down" by swapping with the smaller child
#      28 # until the heap property is restored.
#      29
#      30 # Read more: https://en.wikipedia.org/wiki/Heap_(data_structure)
#      31
#      32 # You can also watch this video, but note it starts indexing at 1 (different math).
#      33 # You may implement a 1-indexed heap if you want (leave index 0 unused), or use 0-indexing.
#      34 # Either approach works:
#      35 # https://www.youtube.com/watch?v=0wPlzMU-k00
#      36
#      37 # For this assignment, the items added to the priority queue can be any object.
#      38 # You will only compute/compare priorities (ints).
#      39 # For peek() and pop(), return (item, priority) as a tuple.
#      42 class MinHeap:
#      43     def __init__(self):
#      44         # We'll store elements as tuples: (priority, item)
#
# NameError: name 'seld' is not defined

# %% [markdown]
# # Testing and Submitting

# %% [markdown]
# Once you are confident in your submission, you can run the unit tests here:

# %%
import unittest

loader = unittest.TestLoader()
suite = loader.discover(".", pattern="test_heap_and_queue.py")

runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite)
# Out:
# priority_queue (unittest.loader._FailedTest.priority_queue) ... ERROR
# test_heap_and_queue (unittest.loader._FailedTest.test_heap_and_queue) ... ERROR
#
# ======================================================================
# ERROR: priority_queue (unittest.loader._FailedTest.priority_queue)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: priority_queue
# Traceback (most recent call last):
#   File "/Users/Melody/.local/share/uv/python/cpython-3.14.2-macos-aarch64-none/lib/python3.14/unittest/loader.py", line 460, in _find_test_path
#     package = self._get_module_from_name(name)
#   File "/Users/Melody/.local/share/uv/python/cpython-3.14.2-macos-aarch64-none/lib/python3.14/unittest/loader.py", line 367, in _get_module_from_name
#     __import__(name)
#     ~~~~~~~~~~^^^^^^
#   File "/Users/Melody/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/priority_queue/__init__.py", line 1, in <module>
#     from .priority_queue import MinHeap, PriorityQueue  # template defaults
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Melody/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/priority_queue/priority_queue.py", line 71
#     self.data.[0], self.data.[-1] = self.data.[-1], self.data.[0]
#               ^
# SyntaxError: invalid syntax
#
#
# ======================================================================
# ERROR: test_heap_and_queue (unittest.loader._FailedTest.test_heap_and_queue)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_heap_and_queue
# Traceback (most recent call last):
#   File "/Users/Melody/.local/share/uv/python/cpython-3.14.2-macos-aarch64-none/lib/python3.14/unittest/loader.py", line 426, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/Users/Melody/.local/share/uv/python/cpython-3.14.2-macos-aarch64-none/lib/python3.14/unittest/loader.py", line 367, in _get_module_from_name
#     __import__(name)
#     ~~~~~~~~~~^^^^^^
#   File "/Users/Melody/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/test_heap_and_queue.py", line 8, in <module>
#     from priority_queue import MinHeap, PriorityQueue
#   File "/Users/Melody/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/priority_queue/__init__.py", line 1, in <module>
#     from .priority_queue import MinHeap, PriorityQueue  # template defaults
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Melody/Documents/University/Spring26/AI/GitHub/priority-queue-melodyxnguyen/priority_queue/priority_queue.py", line 71
#     self.data.[0], self.data.[-1] = self.data.[-1], self.data.[0]
#               ^
# SyntaxError: invalid syntax
#
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# FAILED (errors=2)
# <unittest.runner.TextTestResult run=2 errors=2 failures=0>

# %% [markdown]
# When you are ready to submit, commit your changes and push to GitHub
#
# ```
# git add -u
# git commit -m "YOUR COMMIT MESSAGE HERE"
# git push
# ```
#
# On Github, you can open the "Actions" tab and check that the tests passed remotely as well.
